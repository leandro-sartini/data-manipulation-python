# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('../data/train.csv')

# %%
train.sample(3)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 767          768         0       3            Mangan, Miss. Mary  female
# 844          845         0       3           Culumovic, Mr. Jeso    male
# 339          340         0       1  Blackwell, Mr. Stephen Weart    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 767  30.5      0      0  364850   7.7500   NaN        Q
# 844  17.0      0      0  315090   8.6625   NaN        S
# 339  45.0      0      0  113784  35.5000     T        S

# %%
test = pd.read_csv('../data/test.csv')

# %%
test.sample(3)
# Out:
#      PassengerId  Pclass                         Name     Sex  Age  SibSp  \
# 379         1271       3  Asplund, Master. Carl Edgar    male  5.0      4
# 203         1095       2   Quick, Miss. Winifred Vera  female  8.0      1
# 173         1065       3             Torfa, Mr. Assad    male  NaN      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 379      2  347077  31.3875   NaN        S
# 203      1   26360  26.0000   NaN        S
# 173      0    2673   7.2292   NaN        C

# %%
gender = pd.read_csv('../data/gender_submission.csv')

# %%
gender.sample(3)
# Out:
#      PassengerId  Survived
# 398         1290         0
# 272         1164         1
# 219         1111         0

# %%
list(train.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
train.rename(columns = {'PassengerId' : 'iD_pAssenger'},inplace = True)

# %%
train['EROR'] = np.nan

# %%
train['ERRO2'] = np.nan

# %%
train['nao_e_nulo'] = np.nan

# %%
train.sample(3)
# Out:
#      iD_pAssenger  Survived  Pclass                                  Name  \
# 541           542         0       3  Andersson, Miss. Ingeborg Constanzia
# 693           694         0       3                      Saad, Mr. Khalil
# 565           566         0       3                  Davies, Mr. Alfred J
#
#         Sex   Age  SibSp  Parch     Ticket    Fare Cabin Embarked  EROR  ERRO2
# 541  female   9.0      4      2     347082  31.275   NaN        S   NaN    NaN
# 693    male  25.0      0      0       2672   7.225   NaN        C   NaN    NaN
# 565    male  24.0      2      0  A/4 48871  24.150   NaN        S   NaN    NaN

# %%
train.columns.tolist()
# Out:
# ['iD_pAssenger',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'EROR',
#  'ERRO2']

# %%
col = ['iD_pAssenger',
 'nao_e_nulo',
 'Survived',
 'Pclass',
 'ERRO2',
 'Name',
 'Sex',
 'Age',
 'SibSp',
 'Parch',
 'Ticket',
 'Fare',
 'Cabin',
 'Embarked',
 'EROR',
 ]

# %%
train = train[col]

# %%
train.sample(3)
# Out:
#      iD_pAssenger  nao_e_nulo  Survived  Pclass  ERRO2  \
# 815           816         NaN         0       1    NaN
# 432           433         NaN         1       2    NaN
# 413           414         NaN         0       2    NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 815                                   Fry, Mr. Richard    male   NaN      0
# 432  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 413                     Cunningham, Mr. Alfred Fleming    male   NaN      0
#
#      Parch      Ticket  Fare Cabin Embarked  EROR
# 815      0      112058   0.0  B102        S   NaN
# 432      0  SC/AH 3085  26.0   NaN        S   NaN
# 413      0      239853   0.0   NaN        S   NaN

# %%
train.to_csv('../exercise_data/primeiro_lote.csv')

# %%
test.sample(3)
# Out:
#      PassengerId  Pclass                                  Name   Sex   Age  \
# 310         1202       3                  Cacic, Mr. Jego Grga  male  18.0
# 306         1198       1  Allison, Mr. Hudson Joshua Creighton  male  30.0
# 341         1233       3            Lundstrom, Mr. Thure Edvin  male  32.0
#
#      SibSp  Parch  Ticket      Fare    Cabin Embarked
# 310      0      0  315091    8.6625      NaN        S
# 306      1      2  113781  151.5500  C22 C26        S
# 341      0      0  350403    7.5792      NaN        S

# %%
to_merge = test.loc[:,['PassengerId','Pclass','Sex','Age','Ticket']]

# %%
to_merge.sample(3)
# Out:
#      PassengerId  Pclass     Sex   Age  Ticket
# 364         1256       1  female  25.0   11765
# 389         1281       3    male   6.0  349909
# 301         1193       2    male   NaN  237735

# %%
merged = pd.merge(gender,to_merge,how='left',on='PassengerId')

# %%
merged.sample(3)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  Ticket
# 191         1083         0       1    male   NaN  111163
# 370         1262         0       2    male  21.0   28133
# 359         1251         1       3  female  30.0  349910

# %%
merged.to_csv('../exercise_data/segundo_lote_1.csv')

# %%
test.sample(3)
# Out:
#      PassengerId  Pclass                                               Name  \
# 77           969       1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 337         1229       3                                  Elias, Mr. Joseph
# 184         1076       1  Douglas, Mrs. Frederick Charles (Mary Helene B...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 77   female  55.0      2      0     11770   25.7000     C101        S
# 337    male  39.0      0      2      2675    7.2292      NaN        C
# 184  female  27.0      1      1  PC 17558  247.5208  B58 B60        C

# %%
lote22 = test.loc[:,['PassengerId','Name','SibSp','Parch','Fare','Cabin','Embarked']]

# %%
lote22.sample(3)
# Out:
#      PassengerId                                               Name  SibSp  \
# 90           982  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...      1
# 160         1052                                 Smyth, Miss. Julia      0
# 85           977                                 Khalil, Mr. Betros      1
#
#      Parch     Fare Cabin Embarked
# 90       0  13.9000   NaN        S
# 160      0   7.7333   NaN        Q
# 85       0  14.4542   NaN        C

# %%
lote22.to_csv('../exercise_data/segundo_lote_2.csv')
